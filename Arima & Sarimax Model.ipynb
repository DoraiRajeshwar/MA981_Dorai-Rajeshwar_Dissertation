# %%
# !pip install yfinance
# !pip install tensorflow==2.12.0
# !pip install matplotlib
# !pip install statsmodels
# !pip install tnrange
# !pip install ipywidgets
# !pip install keras
# !pip install tqdm
# !pip install scikit-learn
# !pip install plotly

# %%
import yfinance as yf

# %%
import numpy as np

# %%
import pandas as pd

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
df_Amzn= yf.download("AMZN" , start = "2021-01-01" , interval = '1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(df_Amzn)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  163.500000  163.600006  157.201004  159.331497  159.331497
# 2021-01-05  158.300507  161.169006  158.253006  160.925507  160.925507
# 2021-01-06  157.324005  159.875504  156.557999  156.919006  156.919006
# 2021-01-07  157.850006  160.427002  157.750000  158.108002  158.108002
# 2021-01-08  159.000000  159.531998  157.110001  159.134995  159.134995
# ...                ...         ...         ...         ...         ...
# 2023-08-17  135.460007  136.089996  133.529999  133.979996  133.979996
# 2023-08-18  131.619995  134.070007  131.149994  133.220001  133.220001
# 2023-08-21  133.740005  135.190002  132.710007  134.679993  134.679993
# 2023-08-22  135.080002  135.649994  133.729996  134.250000  134.250000
# 2023-08-23  134.500000  135.949997  133.220001  135.520004  135.520004
#
#               Volume
# Date
# 2021-01-04  88228000
# 2021-01-05  53110000
# 2021-01-06  87896000
# ...

# %%
df_Amzn.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_Amzn.dropna(inplace=True)

# %%
df_Amzn.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
len(df_Amzn)
# Out:
# 664

# %%
df_Amzn.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  664.000000  664.000000  664.000000  664.000000  664.000000
# mean   138.304447  140.106011  136.399009  138.223611  138.223611
# std     29.128491   29.122217   29.088307   29.065069   29.065069
# min     82.800003   83.480003   81.430000   81.820000   81.820000
# 25%    112.324999  114.110003  109.657497  112.382502  112.382502
# 50%    141.893753  144.113998  139.335007  141.326500  141.326500
# 75%    164.981506  166.375622  163.552879  164.904129  164.904129
# max    187.199997  188.654007  184.839493  186.570496  186.570496
#
#              Volume
# count  6.640000e+02
# mean   6.976351e+07
# std    2.805557e+07
# min    2.826480e+07
# 25%    5.194750e+07
# 50%    6.285830e+07
# 75%    7.772450e+07
# max    2.726620e+08

# %%
df_Amzn.info
# Out:
# <bound method DataFrame.info of                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  163.500000  163.600006  157.201004  159.331497  159.331497
# 2021-01-05  158.300507  161.169006  158.253006  160.925507  160.925507
# 2021-01-06  157.324005  159.875504  156.557999  156.919006  156.919006
# 2021-01-07  157.850006  160.427002  157.750000  158.108002  158.108002
# 2021-01-08  159.000000  159.531998  157.110001  159.134995  159.134995
# ...                ...         ...         ...         ...         ...
# 2023-08-17  135.460007  136.089996  133.529999  133.979996  133.979996
# 2023-08-18  131.619995  134.070007  131.149994  133.220001  133.220001
# 2023-08-21  133.740005  135.190002  132.710007  134.679993  134.679993
# 2023-08-22  135.080002  135.649994  133.729996  134.250000  134.250000
# 2023-08-23  134.500000  135.949997  133.220001  135.520004  135.520004
#
#               Volume
# Date
# 2021-01-04  88228000
# 2021-01-05  53110000
# ...

# %%
df_Amzn.plot(figsize=(15,8))
df_Amzn['Close'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['Close'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn.resample(rule='A').max()#Annual prices
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-12-31  187.199997  188.654007  184.839493  186.570496  186.570496
# 2022-12-31  170.438004  171.399994  167.868500  170.404495  170.404495
# 2023-12-31  141.059998  143.630005  139.320007  142.220001  142.220001
#
#                Volume
# Date
# 2021-12-31  199312000
# 2022-12-31  272662000
# 2023-12-31  158154200

# %%
df_Amzn.resample(rule='A').max()['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-12-31  150.250000  150.449997  144.050003  147.597504  147.597504
# 2022-12-31   82.800003   83.480003   81.690002   81.820000   81.820000
# 2023-12-31   83.029999   85.419998   81.430000   83.120003   83.120003
#
#               Volume
# Date
# 2021-12-31  33606000
# 2022-12-31  35088600
# 2023-12-31  28264800

# %%
df_Amzn.resample(rule='A').min()['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn.resample(rule='qs').max()#Quarterly prices
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-01  171.250504  171.699997  168.056503  169.000000  169.000000
# 2021-04-01  176.255997  177.699997  174.160004  175.272003  175.272003
# 2021-07-01  187.199997  188.654007  184.839493  186.570496  186.570496
# 2021-10-01  185.634506  188.107498  183.785995  184.802994  184.802994
# 2022-01-01  170.438004  171.399994  167.868500  170.404495  170.404495
# 2022-04-01  167.741501  168.394501  163.266006  168.346497  168.346497
# 2022-07-01  143.910004  146.570007  142.000000  144.779999  144.779999
# 2022-10-01  120.769997  123.000000  119.790001  121.089996  121.089996
# 2023-01-01  110.250000  114.000000  108.879997  112.910004  112.910004
# 2023-04-01  129.470001  131.490005  128.949997  130.360001  130.360001
# 2023-07-01  141.059998  143.630005  139.320007  142.220001  142.220001
#
#                Volume
# Date
# 2021-01-01  141972000
# 2021-04-01  153648000
# 2021-07-01  199312000
# ...

# %%
df_Amzn.resample(rule='qs').max()['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn.resample(rule='BA').mean()#Business Annual prices
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-12-31  167.286329  168.943683  165.566274  167.193349  167.193349
# 2022-12-30  126.318080  128.419815  123.914148  126.098819  126.098819
# 2023-12-29  111.628323  113.187640  110.209876  111.782298  111.782298
#
#                   Volume
# Date
# 2021-12-31  6.776334e+07
# 2022-12-30  7.608070e+07
# 2023-12-29  6.304566e+07

# %%
df_Amzn.resample(rule='BA').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['Close'].resample(rule='BA').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['Close'].resample(rule='M').mean().plot(kind='bar')#Monthly
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['Close'].resample(rule='M').mean().plot(kind='bar',figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['Close'].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['close:10 days rolling']=df_Amzn['Close'].rolling(10,min_periods=1).mean()

# %%
df_Amzn['close:10 days rolling']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.128502
# 2021-01-06    159.058670
# 2021-01-07    158.821003
# 2021-01-08    158.883801
#                  ...
# 2023-08-17    138.384003
# 2023-08-18    137.749002
# 2023-08-21    136.995001
# 2023-08-22    136.426001
# 2023-08-23    136.193001
# Name: close:10 days rolling, Length: 664, dtype: float64

# %%
df_Amzn[['Close','close:10 days rolling']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['close:20 days rolling']=df_Amzn['Close'].rolling(20,min_periods=1).mean()

# %%
df_Amzn['close:20 days rolling']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.128502
# 2021-01-06    159.058670
# 2021-01-07    158.821003
# 2021-01-08    158.883801
#                  ...
# 2023-08-17    134.143502
# 2023-08-18    134.304502
# 2023-08-21    134.598502
# 2023-08-22    134.854501
# 2023-08-23    135.223002
# Name: close:20 days rolling, Length: 664, dtype: float64

# %%
df_Amzn[['Close','close:20 days rolling']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['close:30 days rolling']=df_Amzn['Close'].rolling(30,min_periods=1).mean()

# %%
df_Amzn['close:30 days rolling']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.128502
# 2021-01-06    159.058670
# 2021-01-07    158.821003
# 2021-01-08    158.883801
#                  ...
# 2023-08-17    133.335001
# 2023-08-18    133.449668
# 2023-08-21    133.701335
# 2023-08-22    133.883668
# 2023-08-23    134.041001
# Name: close:30 days rolling, Length: 664, dtype: float64

# %%
df_Amzn[['Close','close:30 days rolling']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['close:60 days rolling']=df_Amzn['Close'].rolling(60,min_periods=1).mean()

# %%
df_Amzn['close:60 days rolling']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.128502
# 2021-01-06    159.058670
# 2021-01-07    158.821003
# 2021-01-08    158.883801
#                  ...
# 2023-08-17    129.201501
# 2023-08-18    129.505334
# 2023-08-21    129.804167
# 2023-08-22    130.125001
# 2023-08-23    130.381834
# Name: close:60 days rolling, Length: 664, dtype: float64

# %%
df_Amzn[['Close','close:60 days rolling']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['close:90 days rolling']=df_Amzn['Close'].rolling(90,min_periods=1).mean()

# %%
df_Amzn['close:90 days rolling']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.128502
# 2021-01-06    159.058670
# 2021-01-07    158.821003
# 2021-01-08    158.883801
#                  ...
# 2023-08-17    121.749667
# 2023-08-18    122.119667
# 2023-08-21    122.529112
# 2023-08-22    122.883001
# 2023-08-23    123.249778
# Name: close:90 days rolling, Length: 664, dtype: float64

# %%
df_Amzn[['Close','close:90 days rolling']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['close:120 days rolling']=df_Amzn['Close'].rolling(120,min_periods=1).mean()

# %%
df_Amzn['close:120 days rolling']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.128502
# 2021-01-06    159.058670
# 2021-01-07    158.821003
# 2021-01-08    158.883801
#                  ...
# 2023-08-17    115.647750
# 2023-08-18    115.976584
# 2023-08-21    116.313667
# 2023-08-22    116.664334
# 2023-08-23    117.025917
# Name: close:120 days rolling, Length: 664, dtype: float64

# %%
df_Amzn[['Close','close:120 days rolling']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['close:150 days rolling']=df_Amzn['Close'].rolling(150,min_periods=1).mean()

# %%
df_Amzn['close:150 days rolling']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.128502
# 2021-01-06    159.058670
# 2021-01-07    158.821003
# 2021-01-08    158.883801
#                  ...
# 2023-08-17    112.312000
# 2023-08-18    112.565000
# 2023-08-21    112.808734
# 2023-08-22    113.063400
# 2023-08-23    113.330467
# Name: close:150 days rolling, Length: 664, dtype: float64

# %%
df_Amzn[['Close','close:150 days rolling']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['close:180 days rolling']=df_Amzn['Close'].rolling(180,min_periods=1).mean()

# %%
df_Amzn['close:180 days rolling']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.128502
# 2021-01-06    159.058670
# 2021-01-07    158.821003
# 2021-01-08    158.883801
#                  ...
# 2023-08-17    108.305111
# 2023-08-18    108.531778
# 2023-08-21    108.743667
# 2023-08-22    108.958945
# 2023-08-23    109.188889
# Name: close:180 days rolling, Length: 664, dtype: float64

# %%
df_Amzn[['Close','close:180 days rolling']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn[['Close','close:10 days rolling','close:20 days rolling','close:30 days rolling','close:60 days rolling','close:90 days rolling','close:120 days rolling','close:150 days rolling','close:180 days rolling']].plot(xlim=['2022-01-01','2024-01-01'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['Close'].expanding().mean()
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.128502
# 2021-01-06    159.058670
# 2021-01-07    158.821003
# 2021-01-08    158.883801
#                  ...
# 2023-08-17    138.246678
# 2023-08-18    138.239074
# 2023-08-21    138.233697
# 2023-08-22    138.227689
# 2023-08-23    138.223611
# Name: Close, Length: 664, dtype: float64

# %%
df_Amzn['Close'].expanding().mean().plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['EMA_0.1']=df_Amzn['Close'].ewm(alpha=0.1,adjust=False).mean() #calculating the Exponential Moving Average (EMA(t) = Close(t) * alpha + (1 - alpha) * EMA(t-1))

# %%
df_Amzn['EMA_0.1']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    159.490898
# 2021-01-06    159.233709
# 2021-01-07    159.121138
# 2021-01-08    159.122524
#                  ...
# 2023-08-17    135.128574
# 2023-08-18    134.937717
# 2023-08-21    134.911945
# 2023-08-22    134.845750
# 2023-08-23    134.913176
# Name: EMA_0.1, Length: 664, dtype: float64

# %%
df_Amzn[['Close','EMA_0.1']].plot(figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['EMA_0.3']=df_Amzn['Close'].ewm(alpha=0.3,adjust=False).mean()

# %%
df_Amzn['EMA_0.3']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    159.809700
# 2021-01-06    158.942492
# 2021-01-07    158.692145
# 2021-01-08    158.825000
#                  ...
# 2023-08-17    136.359776
# 2023-08-18    135.417844
# 2023-08-21    135.196489
# 2023-08-22    134.912542
# 2023-08-23    135.094781
# Name: EMA_0.3, Length: 664, dtype: float64

# %%
df_Amzn[['Close','EMA_0.3']].plot(figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['EMA_0.6']=df_Amzn['Close'].ewm(alpha=0.6,adjust=False).mean()

# %%
df_Amzn['EMA_0.6']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.287903
# 2021-01-06    158.266565
# 2021-01-07    158.171427
# 2021-01-08    158.749568
#                  ...
# 2023-08-17    134.964072
# 2023-08-18    133.917629
# 2023-08-21    134.375047
# 2023-08-22    134.300019
# 2023-08-23    135.032010
# Name: EMA_0.6, Length: 664, dtype: float64

# %%
df_Amzn[['Close','EMA_0.6']].plot(figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['EMA_0.9']=df_Amzn['Close'].ewm(alpha=0.9,adjust=False).mean()

# %%
df_Amzn['EMA_0.9']
# Out:
# Date
# 2021-01-04    159.331497
# 2021-01-05    160.766106
# 2021-01-06    157.303716
# 2021-01-07    158.027573
# 2021-01-08    159.024252
#                  ...
# 2023-08-17    134.117682
# 2023-08-18    133.309769
# 2023-08-21    134.542970
# 2023-08-22    134.279297
# 2023-08-23    135.395934
# Name: EMA_0.9, Length: 664, dtype: float64

# %%
df_Amzn[['Close','EMA_0.9']].plot(figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn[['Close','EMA_0.1','EMA_0.3','EMA_0.6','EMA_0.9']].plot(figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['EMA_5 days']=df_Amzn['Close'].ewm(span=5).mean() #calculating the Exponential Moving Average using a span of 5 days

# %%
df_Amzn[['Close','EMA_5 days']].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Amzn['EMA_10 days']=df_Amzn['Close'].ewm(span=10).mean() #calculating the Exponential Moving Average using a span of 10 days

# %%
df_Amzn[['Close','EMA_10 days']].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose # Describes the time series data

# %%
from statsmodels.tsa.stattools import adfuller # Used to perform the Augmented Dickey-Fuller (ADF) test and check if data is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf # used to create an Autocorrelation Function (ACF) plot and compute lag for ARIMA

# %%
from statsmodels.graphics.tsaplots import plot_pacf # used to create a Partial Autocorrelation Function (PACF) plot and compute partial lag for ARIMA

# %%
import statsmodels.api as sm

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
x=df_Amzn.reset_index()

# %%
df_close=x[['Date','Close']]

# %%
df_close.dtypes
# Out:
# Date     datetime64[ns]
# Close           float64
# dtype: object

# %%
df_close.set_index("Date", inplace = True)

# %%
df_close = df_close.asfreq("d")

# %%
df_close.isnull().sum()
# Out:
# Close    298
# dtype: int64

# %%
df_close.head(10)
# Out:
#                  Close
# Date
# 2021-01-04  159.331497
# 2021-01-05  160.925507
# 2021-01-06  156.919006
# 2021-01-07  158.108002
# 2021-01-08  159.134995
# 2021-01-09         NaN
# 2021-01-10         NaN
# 2021-01-11  155.710495
# 2021-01-12  156.041504
# 2021-01-13  158.294495

# %%
df_close = df_close.fillna(method  = "bfill")

# %%
df_close.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
df_close.head(10)
# Out:
#                  Close
# Date
# 2021-01-04  159.331497
# 2021-01-05  160.925507
# 2021-01-06  156.919006
# 2021-01-07  158.108002
# 2021-01-08  159.134995
# 2021-01-09  155.710495
# 2021-01-10  155.710495
# 2021-01-11  155.710495
# 2021-01-12  156.041504
# 2021-01-13  158.294495

# %%
df_close.shape
# Out:
# (962, 1)

# %%
df_close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 962 entries, 2021-01-04 to 2023-08-23
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   962 non-null    float64
# dtypes: float64(1)
# memory usage: 15.0 KB

# %%
df_close['Close'].plot(figsize=(20,7))
plt.ylabel("Closing price")
# Out:
# Text(0, 0.5, 'Closing price')

# %%
decomp = seasonal_decompose(df_close, model = "multiplicative") #Decompose the data

# %%
x = decomp.plot()

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adf_test(df_close['Close'])
# Out:
# ADF Statistics: -1.4829472615740378
# p- value: 0.5419295882912045
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
# Since the time series is non-stationary, it implies that the statistical properties, such as the mean and variance, are not constant over time. Non-stationary time series can exhibit trends, seasonality, or other patterns, making them more challenging to analyze using traditional statistical methods.

# To make the time series stationary, you might consider applying transformation techniques like differencing, logarithmic transformation, or seasonal decomposition to remove trends and seasonality. The goal of making the series stationary is to achieve a constant mean and variance over time, which is essential for many time series analyses and forecasting models.

# %%
# Use Techniques Differencing

# %%
df_close['close First Difference']=df_close['Close']-df_close['Close'].shift(1) 
# The first difference of the time series yt is calculated as: First Difference (yt)=yt~yt−1
# The first difference represents the change in the closing price from one day to the next, effectively measuring the daily price changes. Subtracting the 'Close' column from the shifted 'Close' column will yield a new column containing the first difference values.

# %%
df_close.head()
# Out:
#                  Close  close First Difference
# Date
# 2021-01-04  159.331497                     NaN
# 2021-01-05  160.925507                1.594009
# 2021-01-06  156.919006               -4.006500
# 2021-01-07  158.108002                1.188995
# 2021-01-08  159.134995                1.026993

# %%
adf_test(df_close['close First Difference'].dropna())
# Out:
# ADF Statistics: -30.88593822154682
# p- value: 0.0
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
df_close['closing 12 months Difference']=df_close['Close']-df_close['Close'].shift(12)

# %%
adf_test(df_close['closing 12 months Difference'].dropna())
# Out:
# ADF Statistics: -6.697527549561539
# p- value: 3.964777661531717e-09
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
acf = plot_acf(df_close["close First Difference"].dropna())

# %%
acf12=plot_acf(df_close["closing 12 months Difference"].dropna())

# %%
pacf = plot_pacf(df_close["close First Difference"].dropna())

# %%
pacf = plot_pacf(df_close["closing 12 months Difference"].dropna())

# %%
df_close
# Out:
#                  Close  close First Difference  closing 12 months Difference
# Date
# 2021-01-04  159.331497                     NaN                           NaN
# 2021-01-05  160.925507                1.594009                           NaN
# 2021-01-06  156.919006               -4.006500                           NaN
# 2021-01-07  158.108002                1.188995                           NaN
# 2021-01-08  159.134995                1.026993                           NaN
# ...                ...                     ...                           ...
# 2023-08-19  134.679993                1.459991                     -7.540009
# 2023-08-20  134.679993                0.000000                     -5.260010
# 2023-08-21  134.679993                0.000000                     -3.170013
# 2023-08-22  134.250000               -0.429993                     -4.309998
# 2023-08-23  135.520004                1.270004                     -2.889999
#
# [962 rows x 3 columns]

# %%
df_close_1=df_close.drop(['close First Difference', 'closing 12 months Difference'], axis=1)

# %%
df_close_1.head()
# Out:
#                  Close
# Date
# 2021-01-04  159.331497
# 2021-01-05  160.925507
# 2021-01-06  156.919006
# 2021-01-07  158.108002
# 2021-01-08  159.134995

# %%
# Model (train and test set split )

# %%
plt.rcParams.update({"figure.figsize" : (12,5), "lines.linewidth": 2})

# %%
length = int((len(df_close_1)*9)/10)
print(length)
# Out:
# 865

# %%
train = df_close_1[:length]

# %%
train.head()
# Out:
#                  Close
# Date
# 2021-01-04  159.331497
# 2021-01-05  160.925507
# 2021-01-06  156.919006
# 2021-01-07  158.108002
# 2021-01-08  159.134995

# %%
test = df_close_1[length:]

# %%
test
# Out:
#                  Close
# Date
# 2023-05-19  116.250000
# 2023-05-20  115.010002
# 2023-05-21  115.010002
# 2023-05-22  115.010002
# 2023-05-23  114.989998
# ...                ...
# 2023-08-19  134.679993
# 2023-08-20  134.679993
# 2023-08-21  134.679993
# 2023-08-22  134.250000
# 2023-08-23  135.520004
#
# [97 rows x 1 columns]

# %%
plt.figure(figsize=(12,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Closing prices')
plt.plot(train, c='orange' ,label='training data')
plt.plot(test, c='blue' ,label='testing data')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
print(len(train))
print(len(test))
# Out:
# 865
# 97

# %%
# Fit the ARIMA model

# %%
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
import numpy as np


arima_predict = []
arima_model = ARIMA(train['Close'],order=(5,2,0)).fit()
forecast_values= arima_model.forecast(97)
arima_predict.extend(forecast_values)
arima_predict = np.array(arima_predict).reshape((97,))
test['arima_pred'] = arima_predict
arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                  865
# Model:                 ARIMA(5, 2, 0)   Log Likelihood               -2129.254
# Date:                Thu, 24 Aug 2023   AIC                           4270.509
# Time:                        11:01:04   BIC                           4299.071
# Sample:                    01-04-2021   HQIC                          4281.442
#                          - 05-18-2023
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8381      0.026    -32.095      0.000      -0.889      -0.787
# ar.L2         -0.6713      0.036    -18.907      0.000      -0.741      -0.602
# ar.L3         -0.5182      0.041    -12.589      0.000      -0.599      -0.438
# ...

# %%
print((test))
# Out:
#                  Close  arima_pred
# Date
# 2023-05-19  116.250000  119.476334
# 2023-05-20  115.010002  120.796294
# 2023-05-21  115.010002  122.269463
# 2023-05-22  115.010002  124.127224
# 2023-05-23  114.989998  125.920460
# ...                ...         ...
# 2023-08-19  134.679993  274.364681
# 2023-08-20  134.679993  276.051701
# 2023-08-21  134.679993  277.738720
# 2023-08-22  134.250000  279.425739
# 2023-08-23  135.520004  281.112759
#
# [97 rows x 2 columns]

# %%
#from sklearn.metrics import mean_squared_error
#from sklearn.metrics import r2_score
#import math
#errors = mean_squared_error(test['Close'], test['arima_pred'])
#print('Mean Squared Error: %.3f' % errors)
#print('Root Mean Squared Error: %.3f' % math.sqrt(errors))
#print(r2_score(test['Close'], test['arima_pred']))

from sklearn.metrics import mean_absolute_error
# Evaluating the model using MAE Evaluation Metric
print(mean_absolute_error(test['Close'], test['arima_pred']))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(test['Close'], test['arima_pred']))
##R² score also known as the coefficient of determination gives the measure of how good a model fits to a given dataset. 
##It indicates how closer are the predicted values to the actual values.

from sklearn.metrics import r2_score
print(r2_score(test['Close'], test['arima_pred']))
# Out:
# 71.02417912547283
# 6782.234051010264
# -162.6064519451297

# %%
plt.figure(figsize=(14,5))
plt.plot(train['Close'].values, label = 'Train')   
plt.plot([None for i in train.values] + [x for x in test['Close'].values], label = 'Test')
plt.plot([None for i in train.values] + [x for x in test['arima_pred'].values], label = 'ARIMA Prediction')
plt.title('Price prediction w.r.t to time $ ARIMA Prediction Plot', family='Arial', fontsize=20)
plt.xlabel('Time', fontsize=18)
plt.ylabel('Close', fontsize=18)
plt.legend(loc = 'best')

# %%
# Fit the SARIMAX model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
SARIMA_model=SARIMAX(train['Close'],order=(1,1,0),seasonal_order=(0,1,0,12))
SARIMA_fit=SARIMA_model.fit()
SARIMA_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                              Close   No. Observations:                  865
# Model:             SARIMAX(1, 1, 0)x(0, 1, 0, 12)   Log Likelihood               -2349.097
# Date:                            Thu, 24 Aug 2023   AIC                           4702.194
# Time:                                    11:01:08   BIC                           4711.689
# Sample:                                01-04-2021   HQIC                          4705.830
#                                      - 05-18-2023
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0087      0.028      0.312      0.755      -0.046       0.063
# sigma2        14.5326      0.485     29.955      0.000      13.582      15.483
# ...

# %%
pred_start_date=test.index[0]
pred_end_date=test.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 2023-05-19 00:00:00
# 2023-08-23 00:00:00

# %%
from datetime import datetime,timedelta
pred_Sarima=SARIMA_fit.predict(start=datetime(2023,4,20),end=datetime(2023,8,24))
resid=test['Close']-pred_Sarima
SARIMA_fit.resid.plot()
#SARIMA_fit.resid.plot(kind='kde')
test['Predicted_SARIMA']=pred_Sarima
test.head()
# Out:
#                  Close  arima_pred  Predicted_SARIMA
# Date
# 2023-05-19  116.250000  119.476334        118.171537
# 2023-05-20  115.010002  120.796294        118.171724
# 2023-05-21  115.010002  122.269463        118.961727
# 2023-05-22  115.010002  124.127224        122.531726
# 2023-05-23  114.989998  125.920460        124.521724

# %%
test.isna().sum()
# Out:
# Close               0
# arima_pred          0
# Predicted_SARIMA    0
# dtype: int64

# %%
#from sklearn.metrics import mean_squared_error
#from sklearn.metrics import r2_score
#import math
#sarimax_errors = mean_squared_error(test['Close'],test['Predicted_SARIMA'])
#print('Mean Squared Error: %.3f' % sarimax_errors)
#print('Root Mean Squared Error: %.3f' % math.sqrt(sarimax_errors))
#print(r2_score(test['Close'], test['Predicted_SARIMA']))

from sklearn.metrics import mean_absolute_error
# Evaluating the model using MAE Evaluation Metric
print(mean_absolute_error(test['Close'],test['Predicted_SARIMA']))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(test['Close'],test['Predicted_SARIMA']))
##R² score also known as the coefficient of determination gives the measure of how good a model fits to a given dataset. 
##It indicates how closer are the predicted values to the actual values.

from sklearn.metrics import r2_score
print(r2_score(test['Close'],test['Predicted_SARIMA']))
# Out:
# 37.90874822870063
# 1983.6117964832597
# -46.85026373585403

# %%
# Visualization

# %%
plt.plot(test.index, test["Close"], label="actual data")
plt.plot(test.index, test['Predicted_SARIMA'], label="SARIMAX model prediction", color="orange")
plt.legend()

# %%
#Moving on with Deep Learning Model building
